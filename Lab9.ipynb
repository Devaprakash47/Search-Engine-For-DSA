# %% [markdown]
# imports

# %%
from sklearn.datasets import load_breast_cancer
import matplotlib.pyplot as plt
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.svm import SVC
import numpy as np

# %% [markdown]
# dataset

# %%
cancer = load_breast_cancer()
X = cancer.data[:, :2]
y = cancer.target

# %% [markdown]
# train linear SVM

# %%
svm = SVC(kernel="linear", C=1)
svm.fit(X, y)
# Out:
# SVC(C=1, kernel='linear')

# %% [markdown]
# user input

# %%
val1 = float(input(f"Enter value for {cancer.feature_names[0]}: "))
val2 = float(input(f"Enter value for {cancer.feature_names[1]}: "))
# Out:
# Enter value for mean radius: 30
# Enter value for mean texture: 20

# %% [markdown]
# prepare input

# %%
user_X = np.array([[val1, val2]])

# %% [markdown]
# predict class

# %%
pred = svm.predict(user_X)[0]
if pred == 0:
 print("The model predicts: Malignant (cancerous tumor)")
else:
 print("The model predicts: Benign (non-cancerous tumor)")
# Out:
# The model predicts: Malignant (cancerous tumor)

# %% [markdown]
# plot decision boundary and data

# %%
DecisionBoundaryDisplay.from_estimator(
 svm,
 X,
 response_method="predict",
 alpha=0.8,
 cmap="Pastel1",
 xlabel=cancer.feature_names[0],
 ylabel=cancer.feature_names[1],
 )

# %% [markdown]
# plot training

# %%
plt.scatter(X[:, 0], X[:, 1],
 c=y,
 s=20, edgecolors="k" , label="Training data")

# %% [markdown]
# plot userinput

# %%
plt.scatter(user_X[0, 0], user_X[0, 1],
 c="red" if pred == 0 else "green",
 marker="*", s=200, edgecolors="k",
 label="User input")
plt.legend()
plt.show()
